# %% [markdown]
# <a href="https://colab.research.google.com/github/NahuelCostaCortez/taller-IA/blob/main/3_1ChatWithPdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown # Descargar archivos e instalar dependencias
from IPython.display import clear_output
# !git clone https://github.com/NahuelCostaCortez/taller-IA
# !pip install -r taller-IA/chatwithPDF/requirements.txt
clear_output()

#@markdown IMPORTANTE: una vez termine de ejecutar esta celda es necesario reiniciar el entorno:

#@markdown - Ir a "Entorno de ejecución" - "Reiniciar entorno de ejecución"
#@markdown - Una vez reiniciado seguir ejecutando desde la siguiente celda

# %%
#@markdown # Lanzar demo
# !python taller-IA/chatwithPDF/app.py

#@markdown Pulsar en la URL de _Running on public URL_
# Out:
# /usr/local/lib/python3.9/dist-packages/gradio/utils.py:875: UserWarning: Expected 3 arguments for function <function pdf_changes at 0x7fc6ca89bca0>, received 2.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/gradio/utils.py:879: UserWarning: Expected at least 3 arguments for function <function pdf_changes at 0x7fc6ca89bca0>, received 2.
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://3a74f371d72d65f438.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
